# %% [markdown]
# # Seaborn
#
# https://seaborn.pydata.org/index.html

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from scipy import stats

import seaborn as sns
sns.set(style="ticks", color_codes=True)

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.catplot(x="day", y="total_bill", data=tips)#kind="strip"; the default
sns.catplot(x="day", y="total_bill", jitter=False, data=tips)

# %%
print("swarm")
sns.catplot(x="day", y="total_bill", kind="swarm", data=tips)
# Out:
# swarm

# %%
print("box")
sns.catplot(x="day", y="total_bill", kind="box", data=tips)
# Out:
# box

# %%
print("violin")
sns.catplot(x="day", y="total_bill", kind="violin", data=tips)
# Out:
# violin

# %%
print("boxen")
sns.catplot(x="day", y="total_bill", kind="boxen", data=tips)
# Out:
# boxen

# %% [markdown]
# # seaborn.pointplot
# Show point estimates and confidence intervals using scatter plot glyphs.
#
# A point plot represents an estimate of central tendency for a numeric variable by the position of scatter plot points and provides some indication of the uncertainty around that estimate using error bars.

# %%
print("point")
sns.catplot(x="day", y="total_bill", kind="point", data=tips)
# Out:
# point

# %%
print("bar")
sns.catplot(x="day", y="total_bill", kind="bar", data=tips)
# Out:
# bar

# %%
tips.total_bill.mean()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
print("count")
sns.catplot(x="day", kind="count", data=tips, palette="ch:.25", hue='size',col='sex',row='smoker') 
#kind="strip","swarm","box","violin","boxen","point","bar","count"
# Out:
# count

# %%
means=tips.total_bill.mean()
g = sns.catplot(x="total_bill", y="sex", row="day",
                kind="box", orient="h", height=1.5, aspect=4,
                data=tips.query("total_bill>19.785943"))
g.set(xscale="log")
